# %%
import cv2
import tensorflow as tf
import keras

CATEGORIES = ["Hamza", "Others"]

def prepare(filepath):
    IMG_SIZE = 200
    img_array = cv2.imread(filepath, cv2.COLOR_BGR2RGB)
    new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
    return new_array.reshape(-1, IMG_SIZE, IMG_SIZE, 3)
model = tf.keras.models.load_model("hamza.model")

# %%
#import matplotlib.pyplot as plt
import tensorflow as tf
import matplotlib.pyplot as plt
import cv2
import os
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image

# %%
imgtest=plt.imread("C:/Users/MASROUR/pyproj/my_env/basedata/testing/IMG-20190601-WA0027.jpg")
img=plt.imshow(imgtest)
#prevision = model.predict(np.array([img]))
#prevision

# %%
from skimage.transform import resize

# %%
resized = resize(imgtest,(500,500,3))
img=plt.imshow(resized)

# %%
dir_path = "C:/Users/MASROUR/pyproj/my_env/basedata/testing"
for i in os.listdir(dir_path):
    img = image.load_img(dir_path+'//'+i,target_size=(200,200))
    plt.imshow(img)
    plt.show()
   # X = image.img_to_array(img)
   # X = np.expand_dims(X,axis =0)
   # images = np.vstack([X])

    prediction = model.predict([prepare("C:/Users/MASROUR/pyproj/my_env/basedata/testing"+'//'+i)])
    print(CATEGORIES[int(prediction[0][0])])
# Out:
# Others
# Others
# Hamza
# Hamza
# Hamza
# Others
# Hamza
# Hamza
# Others
# Others
# Hamza
# Hamza
# Hamza
# Hamza
# Hamza
# Hamza
# Others
